# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
from citipy import citipy

# %%
# create a list for holding the cities
cities = []
# Identify the nearest city for each latitude and longitude combination
for coordinate in lat_lngs:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 736

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description})

    # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | provideniya
# Processing Record 2 of Set 1 | ribeira grande
# Processing Record 3 of Set 1 | broome
# Processing Record 4 of Set 1 | bubaque
# Processing Record 5 of Set 1 | punta arenas
# Processing Record 6 of Set 1 | qaanaaq
# Processing Record 7 of Set 1 | melo
# Processing Record 8 of Set 1 | mount isa
# Processing Record 9 of Set 1 | tutoia
# Processing Record 10 of Set 1 | ushuaia
# Processing Record 11 of Set 1 | longyearbyen
# Processing Record 12 of Set 1 | brookhaven
# Processing Record 13 of Set 1 | arraial do cabo
# Processing Record 14 of Set 1 | hithadhoo
# Processing Record 15 of Set 1 | alofi
# Processing Record 16 of Set 1 | khatanga
# Processing Record 17 of Set 1 | hilo
# Processing Record 18 of Set 1 | vao
# Processing Record 19 of Set 1 | mitu
# Processing Record 20 of Set 1 | tuatapere
# Processing Record 21 of Set 1 | mar del plata
# Processing Record 22 of Set 1 | brewster
# Processing Record 23 of Set 1 | saskylakh
# Processing Record 24 of Set 1 | bredasdorp
# Processing Record 25 of Set 1 | port elizabeth
# Processing Record 26 of Set 1 | bluff
# Processing Record 27 of Set 1 | jamestown
# Processing Record 28 of Set 1 | gat
# Processing Record 29 of Set 1 | socorro
# Processing Record 30 of Set 1 | pangnirtung
# Processing Record 31 of Set 1 | albany
# Processing Record 32 of Set 1 | nyrob
# Processing Record 33 of Set 1 | vilhena
# City not found. Skipping...
# Processing Record 34 of Set 1 | galiwinku
# Processing Record 35 of Set 1 | georgetown
# Processing Record 36 of Set 1 | ponta do sol
# City not found. Skipping...
# Processing Record 37 of Set 1 | illoqqortoormiut
# Processing Record 38 of Set 1 | ilulissat
# City not found. Skipping...
# Processing Record 39 of Set 1 | barentsburg
# Processing Record 40 of Set 1 | shaoguan
# Processing Record 41 of Set 1 | atuona
# Processing Record 42 of Set 1 | kavieng
# Processing Record 43 of Set 1 | dikson
# Processing Record 44 of Set 1 | guerrero negro
# Processing Record 45 of Set 1 | cherskiy
# Processing Record 46 of Set 1 | pingliang
# City not found. Skipping...
# Processing Record 47 of Set 1 | linchuan
# Processing Record 48 of Set 1 | faanui
# Processing Record 49 of Set 1 | mataura
# Processing Record 50 of Set 1 | rikitea
# Processing Record 1 of Set 2 | rocha
# Processing Record 2 of Set 2 | scottsbluff
# Processing Record 3 of Set 2 | hambantota
# Processing Record 4 of Set 2 | clyde river
# Processing Record 5 of Set 2 | new norfolk
# Processing Record 6 of Set 2 | arona
# Processing Record 7 of Set 2 | tiksi
# Processing Record 8 of Set 2 | iranshahr
# Processing Record 9 of Set 2 | roma
# Processing Record 10 of Set 2 | lebu
# Processing Record 11 of Set 2 | qobustan
# Processing Record 12 of Set 2 | kapaa
# Processing Record 13 of Set 2 | narsaq
# Processing Record 14 of Set 2 | carnarvon
# Processing Record 15 of Set 2 | banda aceh
# Processing Record 16 of Set 2 | manjacaze
# Processing Record 17 of Set 2 | arcata
# Processing Record 18 of Set 2 | lieksa
# Processing Record 19 of Set 2 | thompson
# City not found. Skipping...
# Processing Record 20 of Set 2 | satitoa
# Processing Record 21 of Set 2 | vaini
# City not found. Skipping...
# Processing Record 22 of Set 2 | belushya guba
# Processing Record 23 of Set 2 | cape town
# City not found. Skipping...
# Processing Record 24 of Set 2 | palabuhanratu
# Processing Record 25 of Set 2 | butaritari
# Processing Record 26 of Set 2 | bambous virieux
# Processing Record 27 of Set 2 | alice springs
# Processing Record 28 of Set 2 | kalanchak
# Processing Record 29 of Set 2 | brae
# Processing Record 30 of Set 2 | upernavik
# Processing Record 31 of Set 2 | bogorodskoye
# Processing Record 32 of Set 2 | birjand
# Processing Record 33 of Set 2 | barrow
# Processing Record 34 of Set 2 | san jose
# Processing Record 35 of Set 2 | haines junction
# Processing Record 36 of Set 2 | hobart
# Processing Record 37 of Set 2 | mahebourg
# Processing Record 38 of Set 2 | ossora
# Processing Record 39 of Set 2 | anadyr
# Processing Record 40 of Set 2 | port alfred
# Processing Record 41 of Set 2 | hasaki
# City not found. Skipping...
# Processing Record 42 of Set 2 | mys shmidta
# Processing Record 43 of Set 2 | houston
# Processing Record 44 of Set 2 | nikolskoye
# Processing Record 45 of Set 2 | paris
# Processing Record 46 of Set 2 | jinchang
# Processing Record 47 of Set 2 | camana
# Processing Record 48 of Set 2 | cidreira
# Processing Record 49 of Set 2 | kalmunai
# Processing Record 50 of Set 2 | umm kaddadah
# Processing Record 1 of Set 3 | karpathos
# Processing Record 2 of Set 3 | norman wells
# Processing Record 3 of Set 3 | puerto ayora
# Processing Record 4 of Set 3 | kargasok
# Processing Record 5 of Set 3 | barra dos coqueiros
# City not found. Skipping...
# Processing Record 6 of Set 3 | sentyabrskiy
# Processing Record 7 of Set 3 | cobija
# Processing Record 8 of Set 3 | ilebo
# Processing Record 9 of Set 3 | carutapera
# Processing Record 10 of Set 3 | nova olimpia
# Processing Record 11 of Set 3 | jamnagar
# City not found. Skipping...
# Processing Record 12 of Set 3 | umm durman
# Processing Record 13 of Set 3 | shingu
# Processing Record 14 of Set 3 | porto tolle
# City not found. Skipping...
# Processing Record 15 of Set 3 | andevoranto
# Processing Record 16 of Set 3 | nsanje
# Processing Record 17 of Set 3 | abu samrah
# Processing Record 18 of Set 3 | pisco
# City not found. Skipping...
# Processing Record 19 of Set 3 | viligili
# Processing Record 20 of Set 3 | victoria
# Processing Record 21 of Set 3 | castro
# Processing Record 22 of Set 3 | ponnani
# Processing Record 23 of Set 3 | saint george
# Processing Record 24 of Set 3 | east london
# Processing Record 25 of Set 3 | tugdan
# Processing Record 26 of Set 3 | souillac
# Processing Record 27 of Set 3 | byron bay
# Processing Record 28 of Set 3 | cervo
# Processing Record 29 of Set 3 | zhigansk
# Processing Record 30 of Set 3 | westport
# Processing Record 31 of Set 3 | hermanus
# Processing Record 32 of Set 3 | conceicao do mato dentro
# Processing Record 33 of Set 3 | nanortalik
# Processing Record 34 of Set 3 | port lincoln
# Processing Record 35 of Set 3 | busselton
# Processing Record 36 of Set 3 | airai
# City not found. Skipping...
# Processing Record 37 of Set 3 | amderma
# Processing Record 38 of Set 3 | saint-philippe
# Processing Record 39 of Set 3 | almaznyy
# Processing Record 40 of Set 3 | palu
# Processing Record 41 of Set 3 | victoria point
# Processing Record 42 of Set 3 | margate
# Processing Record 43 of Set 3 | xining
# Processing Record 44 of Set 3 | bahia honda
# Processing Record 45 of Set 3 | kruisfontein
# Processing Record 46 of Set 3 | banfora
# Processing Record 47 of Set 3 | mount gambier
# Processing Record 48 of Set 3 | ancud
# Processing Record 49 of Set 3 | avarua
# Processing Record 50 of Set 3 | balkanabat
# Processing Record 1 of Set 4 | hofn
# Processing Record 2 of Set 4 | kahului
# City not found. Skipping...
# Processing Record 3 of Set 4 | taolanaro
# Processing Record 4 of Set 4 | dauphin
# Processing Record 5 of Set 4 | udachnyy
# Processing Record 6 of Set 4 | sangar
# City not found. Skipping...
# Processing Record 7 of Set 4 | haibowan
# Processing Record 8 of Set 4 | hue
# Processing Record 9 of Set 4 | sile
# Processing Record 10 of Set 4 | waterloo
# Processing Record 11 of Set 4 | tuktoyaktuk
# Processing Record 12 of Set 4 | lagoa
# Processing Record 13 of Set 4 | chaibasa
# Processing Record 14 of Set 4 | ketchikan
# Processing Record 15 of Set 4 | pevek
# Processing Record 16 of Set 4 | cururupu
# Processing Record 17 of Set 4 | el centro
# Processing Record 18 of Set 4 | tasiilaq
# Processing Record 19 of Set 4 | itarema
# Processing Record 20 of Set 4 | usinsk
# Processing Record 21 of Set 4 | edd
# Processing Record 22 of Set 4 | sisimiut
# Processing Record 23 of Set 4 | esperance
# Processing Record 24 of Set 4 | kununurra
# Processing Record 25 of Set 4 | lata
# Processing Record 26 of Set 4 | denpasar
# Processing Record 27 of Set 4 | magadan
# Processing Record 28 of Set 4 | yilan
# City not found. Skipping...
# Processing Record 29 of Set 4 | nizhneyansk
# Processing Record 30 of Set 4 | lake havasu city
# Processing Record 31 of Set 4 | susuman
# Processing Record 32 of Set 4 | nemuro
# Processing Record 33 of Set 4 | crotone
# City not found. Skipping...
# Processing Record 34 of Set 4 | alotau
# Processing Record 35 of Set 4 | mayahi
# Processing Record 36 of Set 4 | shelopugino
# Processing Record 37 of Set 4 | bintulu
# Processing Record 38 of Set 4 | praia da vitoria
# Processing Record 39 of Set 4 | adrar
# Processing Record 40 of Set 4 | roebourne
# Processing Record 41 of Set 4 | durban
# Processing Record 42 of Set 4 | ballina
# Processing Record 43 of Set 4 | kushiro
# Processing Record 44 of Set 4 | tashtagol
# Processing Record 45 of Set 4 | yaan
# Processing Record 46 of Set 4 | nemea
# Processing Record 47 of Set 4 | galle
# Processing Record 48 of Set 4 | binabalian
# Processing Record 49 of Set 4 | prince rupert
# Processing Record 50 of Set 4 | freeport
# Processing Record 1 of Set 5 | innisfail
# City not found. Skipping...
# Processing Record 2 of Set 5 | kazalinsk
# Processing Record 3 of Set 5 | krasnoselkup
# Processing Record 4 of Set 5 | port hardy
# Processing Record 5 of Set 5 | lodja
# Processing Record 6 of Set 5 | yarovoye
# Processing Record 7 of Set 5 | cortez
# Processing Record 8 of Set 5 | contamana
# Processing Record 9 of Set 5 | karratha
# Processing Record 10 of Set 5 | cozumel
# Processing Record 11 of Set 5 | latung
# Processing Record 12 of Set 5 | antalaha
# Processing Record 13 of Set 5 | jiwani
# Processing Record 14 of Set 5 | rio grande
# Processing Record 15 of Set 5 | shimoda
# City not found. Skipping...
# Processing Record 16 of Set 5 | umzimvubu
# Processing Record 17 of Set 5 | kudahuvadhoo
# Processing Record 18 of Set 5 | herat
# Processing Record 19 of Set 5 | launceston
# City not found. Skipping...
# Processing Record 20 of Set 5 | khomeynishahr
# City not found. Skipping...
# Processing Record 21 of Set 5 | tsihombe
# Processing Record 22 of Set 5 | namibe
# Processing Record 23 of Set 5 | yellowknife
# Processing Record 24 of Set 5 | sorland
# Processing Record 25 of Set 5 | kawalu
# Processing Record 26 of Set 5 | kodiak
# Processing Record 27 of Set 5 | saint-francois
# Processing Record 28 of Set 5 | labytnangi
# Processing Record 29 of Set 5 | kamenka
# Processing Record 30 of Set 5 | vila velha
# Processing Record 31 of Set 5 | aykhal
# City not found. Skipping...
# Processing Record 32 of Set 5 | bolungarvik
# Processing Record 33 of Set 5 | komsomolskiy
# Processing Record 34 of Set 5 | skoghall
# Processing Record 35 of Set 5 | talnakh
# Processing Record 36 of Set 5 | bathsheba
# City not found. Skipping...
# Processing Record 37 of Set 5 | grand river south east
# Processing Record 38 of Set 5 | katsuura
# Processing Record 39 of Set 5 | finspang
# Processing Record 40 of Set 5 | zhaotong
# City not found. Skipping...
# Processing Record 41 of Set 5 | maghama
# Processing Record 42 of Set 5 | kaitangata
# Processing Record 43 of Set 5 | yar-sale
# City not found. Skipping...
# Processing Record 44 of Set 5 | attawapiskat
# Processing Record 45 of Set 5 | maple creek
# Processing Record 46 of Set 5 | bilibino
# City not found. Skipping...
# Processing Record 47 of Set 5 | cheuskiny
# Processing Record 48 of Set 5 | turukhansk
# Processing Record 49 of Set 5 | ape
# Processing Record 50 of Set 5 | zaozerne
# Processing Record 1 of Set 6 | simpang
# Processing Record 2 of Set 6 | kirakira
# Processing Record 3 of Set 6 | pijino
# Processing Record 4 of Set 6 | leua
# Processing Record 5 of Set 6 | pundaguitan
# Processing Record 6 of Set 6 | weyburn
# Processing Record 7 of Set 6 | chancay
# Processing Record 8 of Set 6 | luderitz
# Processing Record 9 of Set 6 | bengkulu
# Processing Record 10 of Set 6 | matagami
# Processing Record 11 of Set 6 | fort morgan
# Processing Record 12 of Set 6 | ostrovnoy
# Processing Record 13 of Set 6 | kiunga
# Processing Record 14 of Set 6 | yorosso
# Processing Record 15 of Set 6 | amasia
# Processing Record 16 of Set 6 | torbay
# Processing Record 17 of Set 6 | kushmurun
# Processing Record 18 of Set 6 | blairmore
# Processing Record 19 of Set 6 | turochak
# Processing Record 20 of Set 6 | qaqortoq
# Processing Record 21 of Set 6 | balatonkenese
# Processing Record 22 of Set 6 | mosquera
# City not found. Skipping...
# Processing Record 23 of Set 6 | tarudant
# Processing Record 24 of Set 6 | ingleside
# Processing Record 25 of Set 6 | flinders
# Processing Record 26 of Set 6 | mount pleasant
# Processing Record 27 of Set 6 | turbat
# Processing Record 28 of Set 6 | saldanha
# Processing Record 29 of Set 6 | umm lajj
# Processing Record 30 of Set 6 | tual
# Processing Record 31 of Set 6 | boa vista
# City not found. Skipping...
# Processing Record 32 of Set 6 | wulanhaote
# Processing Record 33 of Set 6 | kloulklubed
# Processing Record 34 of Set 6 | turba
# Processing Record 35 of Set 6 | klaksvik
# Processing Record 36 of Set 6 | tete
# Processing Record 37 of Set 6 | bowen
# Processing Record 38 of Set 6 | the valley
# Processing Record 39 of Set 6 | hay river
# Processing Record 40 of Set 6 | paamiut
# Processing Record 41 of Set 6 | russell
# Processing Record 42 of Set 6 | salamiyah
# Processing Record 43 of Set 6 | awbari
# City not found. Skipping...
# Processing Record 44 of Set 6 | tumannyy
# Processing Record 45 of Set 6 | san ignacio
# Processing Record 46 of Set 6 | te anau
# Processing Record 47 of Set 6 | havelock
# Processing Record 48 of Set 6 | ulaanbaatar
# Processing Record 49 of Set 6 | longhua
# Processing Record 50 of Set 6 | kropotkin
# Processing Record 1 of Set 7 | dulovo
# Processing Record 2 of Set 7 | ewa beach
# Processing Record 3 of Set 7 | impfondo
# Processing Record 4 of Set 7 | fort nelson
# Processing Record 5 of Set 7 | gaya
# Processing Record 6 of Set 7 | skibbereen
# Processing Record 7 of Set 7 | sitka
# Processing Record 8 of Set 7 | nishihara
# Processing Record 9 of Set 7 | trinidad
# Processing Record 10 of Set 7 | yatou
# Processing Record 11 of Set 7 | cumberland
# Processing Record 12 of Set 7 | yenotayevka
# Processing Record 13 of Set 7 | chaves
# Processing Record 14 of Set 7 | lorengau
# Processing Record 15 of Set 7 | sergeyevka
# City not found. Skipping...
# Processing Record 16 of Set 7 | vaitupu
# Processing Record 17 of Set 7 | salalah
# Processing Record 18 of Set 7 | penne
# Processing Record 19 of Set 7 | codrington
# Processing Record 20 of Set 7 | wichian buri
# Processing Record 21 of Set 7 | beroroha
# Processing Record 22 of Set 7 | monrovia
# Processing Record 23 of Set 7 | olafsvik
# Processing Record 24 of Set 7 | san patricio
# Processing Record 25 of Set 7 | fortuna
# Processing Record 26 of Set 7 | berdigestyakh
# Processing Record 27 of Set 7 | le port
# Processing Record 28 of Set 7 | mnogovershinnyy
# Processing Record 29 of Set 7 | ciudad guayana
# Processing Record 30 of Set 7 | rio gallegos
# Processing Record 31 of Set 7 | tommot
# Processing Record 32 of Set 7 | omboue
# Processing Record 33 of Set 7 | turgenevo
# Processing Record 34 of Set 7 | nouadhibou
# Processing Record 35 of Set 7 | chuy
# Processing Record 36 of Set 7 | vilyuysk
# City not found. Skipping...
# Processing Record 37 of Set 7 | warqla
# Processing Record 38 of Set 7 | lac du bonnet
# Processing Record 39 of Set 7 | lompoc
# Processing Record 40 of Set 7 | kenora
# Processing Record 41 of Set 7 | ambilobe
# Processing Record 42 of Set 7 | ixtapa
# Processing Record 43 of Set 7 | yala
# Processing Record 44 of Set 7 | kochevo
# Processing Record 45 of Set 7 | sao filipe
# Processing Record 46 of Set 7 | taoudenni
# Processing Record 47 of Set 7 | san policarpo
# Processing Record 48 of Set 7 | andreyevo
# Processing Record 49 of Set 7 | bridgetown
# City not found. Skipping...
# Processing Record 50 of Set 7 | skalistyy
# Processing Record 1 of Set 8 | araguaina
# Processing Record 2 of Set 8 | borskoye
# Processing Record 3 of Set 8 | dudinka
# Processing Record 4 of Set 8 | nagato
# Processing Record 5 of Set 8 | coihaique
# Processing Record 6 of Set 8 | auki
# Processing Record 7 of Set 8 | acajutla
# Processing Record 8 of Set 8 | talaya
# Processing Record 9 of Set 8 | sinnamary
# Processing Record 10 of Set 8 | aljezur
# Processing Record 11 of Set 8 | muhos
# Processing Record 12 of Set 8 | vaitape
# Processing Record 13 of Set 8 | kalianget
# Processing Record 14 of Set 8 | chimoio
# Processing Record 15 of Set 8 | bilma
# Processing Record 16 of Set 8 | severo-kurilsk
# Processing Record 17 of Set 8 | changping
# Processing Record 18 of Set 8 | isangel
# City not found. Skipping...
# Processing Record 19 of Set 8 | bargal
# Processing Record 20 of Set 8 | kedrovyy
# Processing Record 21 of Set 8 | suntar
# Processing Record 22 of Set 8 | koslan
# Processing Record 23 of Set 8 | yinchuan
# Processing Record 24 of Set 8 | praya
# Processing Record 25 of Set 8 | asadabad
# Processing Record 26 of Set 8 | bereda
# Processing Record 27 of Set 8 | jhanjharpur
# City not found. Skipping...
# Processing Record 28 of Set 8 | tambul
# City not found. Skipping...
# Processing Record 29 of Set 8 | saleaula
# Processing Record 30 of Set 8 | touros
# Processing Record 31 of Set 8 | petauke
# City not found. Skipping...
# Processing Record 32 of Set 8 | kuche
# City not found. Skipping...
# Processing Record 33 of Set 8 | barbar
# Processing Record 34 of Set 8 | slave lake
# Processing Record 35 of Set 8 | wil
# Processing Record 36 of Set 8 | gamba
# Processing Record 37 of Set 8 | tacuarembo
# Processing Record 38 of Set 8 | igbo ora
# Processing Record 39 of Set 8 | shambu
# Processing Record 40 of Set 8 | kaduna
# Processing Record 41 of Set 8 | avera
# Processing Record 42 of Set 8 | saint anthony
# Processing Record 43 of Set 8 | laguna
# Processing Record 44 of Set 8 | catamarca
# Processing Record 45 of Set 8 | abu dhabi
# Processing Record 46 of Set 8 | nelson bay
# City not found. Skipping...
# Processing Record 47 of Set 8 | halalo
# Processing Record 48 of Set 8 | atagay
# Processing Record 49 of Set 8 | rapid valley
# Processing Record 50 of Set 8 | sokur
# Processing Record 1 of Set 9 | camacha
# Processing Record 2 of Set 9 | fairbanks
# Processing Record 3 of Set 9 | aanekoski
# Processing Record 4 of Set 9 | dinajpur
# Processing Record 5 of Set 9 | gewane
# Processing Record 6 of Set 9 | geraldton
# Processing Record 7 of Set 9 | aklavik
# Processing Record 8 of Set 9 | wajid
# Processing Record 9 of Set 9 | saint-paul
# Processing Record 10 of Set 9 | general artigas
# Processing Record 11 of Set 9 | samarai
# Processing Record 12 of Set 9 | clarence town
# Processing Record 13 of Set 9 | zeerust
# Processing Record 14 of Set 9 | waddan
# Processing Record 15 of Set 9 | north bend
# City not found. Skipping...
# Processing Record 16 of Set 9 | barawe
# Processing Record 17 of Set 9 | duncan
# Processing Record 18 of Set 9 | methoni
# Processing Record 19 of Set 9 | lewistown
# Processing Record 20 of Set 9 | harper
# Processing Record 21 of Set 9 | san francisco
# Processing Record 22 of Set 9 | tomatlan
# Processing Record 23 of Set 9 | acaponeta
# Processing Record 24 of Set 9 | slavsk
# Processing Record 25 of Set 9 | maungatapere
# Processing Record 26 of Set 9 | hamilton
# Processing Record 27 of Set 9 | mareeba
# Processing Record 28 of Set 9 | blagoyevo
# Processing Record 29 of Set 9 | severomuysk
# Processing Record 30 of Set 9 | newnan
# Processing Record 31 of Set 9 | yerbogachen
# City not found. Skipping...
# Processing Record 32 of Set 9 | fort saint john
# Processing Record 33 of Set 9 | papara
# Processing Record 34 of Set 9 | ushtobe
# Processing Record 35 of Set 9 | evensk
# Processing Record 36 of Set 9 | zonguldak
# Processing Record 37 of Set 9 | broken hill
# Processing Record 38 of Set 9 | trieste
# Processing Record 39 of Set 9 | pangody
# Processing Record 40 of Set 9 | hirara
# Processing Record 41 of Set 9 | kenai
# Processing Record 42 of Set 9 | lafia
# Processing Record 43 of Set 9 | pacific grove
# City not found. Skipping...
# Processing Record 44 of Set 9 | westpunt
# Processing Record 45 of Set 9 | petatlan
# Processing Record 46 of Set 9 | berlevag
# Processing Record 47 of Set 9 | santa isabel
# Processing Record 48 of Set 9 | sibolga
# Processing Record 49 of Set 9 | qujing
# Processing Record 50 of Set 9 | baracoa
# Processing Record 1 of Set 10 | butembo
# Processing Record 2 of Set 10 | ahipara
# Processing Record 3 of Set 10 | pergine valsugana
# Processing Record 4 of Set 10 | popondetta
# City not found. Skipping...
# Processing Record 5 of Set 10 | sorvag
# Processing Record 6 of Set 10 | anastacio
# Processing Record 7 of Set 10 | aswan
# Processing Record 8 of Set 10 | oussouye
# Processing Record 9 of Set 10 | turkmenabat
# Processing Record 10 of Set 10 | muisne
# City not found. Skipping...
# Processing Record 11 of Set 10 | mrirt
# Processing Record 12 of Set 10 | cap malheureux
# Processing Record 13 of Set 10 | tagusao
# Processing Record 14 of Set 10 | havre-saint-pierre
# City not found. Skipping...
# Processing Record 15 of Set 10 | karaul
# Processing Record 16 of Set 10 | chernyshevskiy
# Processing Record 17 of Set 10 | luganville
# City not found. Skipping...
# Processing Record 18 of Set 10 | lalomanu
# City not found. Skipping...
# Processing Record 19 of Set 10 | wahran
# Processing Record 20 of Set 10 | northam
# Processing Record 21 of Set 10 | naze
# Processing Record 22 of Set 10 | portland
# Processing Record 23 of Set 10 | ouadda
# Processing Record 24 of Set 10 | shahrud
# Processing Record 25 of Set 10 | chokurdakh
# Processing Record 26 of Set 10 | ankazoabo
# Processing Record 27 of Set 10 | strohonivka
# Processing Record 28 of Set 10 | beringovskiy
# Processing Record 29 of Set 10 | kizilskoye
# Processing Record 30 of Set 10 | macusani
# Processing Record 31 of Set 10 | jaque
# Processing Record 32 of Set 10 | aitape
# Processing Record 33 of Set 10 | dubbo
# Processing Record 34 of Set 10 | pishin
# Processing Record 35 of Set 10 | storforshei
# City not found. Skipping...
# Processing Record 36 of Set 10 | gilazi
# City not found. Skipping...
# Processing Record 37 of Set 10 | santa eulalia del rio
# Processing Record 38 of Set 10 | tecoanapa
# Processing Record 39 of Set 10 | sovetskiy
# Processing Record 40 of Set 10 | muyezerskiy
# Processing Record 41 of Set 10 | dano
# Processing Record 42 of Set 10 | tabou
# Processing Record 43 of Set 10 | kysyl-syr
# Processing Record 44 of Set 10 | hienghene
# Processing Record 45 of Set 10 | lagos
# Processing Record 46 of Set 10 | nome
# Processing Record 47 of Set 10 | san lorenzo
# Processing Record 48 of Set 10 | seoul
# Processing Record 49 of Set 10 | leningradskiy
# Processing Record 50 of Set 10 | puerto cabezas
# Processing Record 1 of Set 11 | bari
# Processing Record 2 of Set 11 | maningrida
# Processing Record 3 of Set 11 | pokhara
# Processing Record 4 of Set 11 | ishigaki
# Processing Record 5 of Set 11 | pochutla
# Processing Record 6 of Set 11 | wuda
# Processing Record 7 of Set 11 | teguldet
# Processing Record 8 of Set 11 | lake city
# Processing Record 9 of Set 11 | daru
# City not found. Skipping...
# Processing Record 10 of Set 11 | gurskoye
# Processing Record 11 of Set 11 | hongjiang
# Processing Record 12 of Set 11 | baruun-urt
# City not found. Skipping...
# Processing Record 13 of Set 11 | chagda
# City not found. Skipping...
# Processing Record 14 of Set 11 | krivopolyanye
# Processing Record 15 of Set 11 | acapulco
# Processing Record 16 of Set 11 | weligama
# Processing Record 17 of Set 11 | spokoynaya
# Processing Record 18 of Set 11 | agirish
# Processing Record 19 of Set 11 | villa carlos paz
# City not found. Skipping...
# Processing Record 20 of Set 11 | meyungs
# Processing Record 21 of Set 11 | deputatskiy
# Processing Record 22 of Set 11 | parrita
# Processing Record 23 of Set 11 | erzin
# Processing Record 24 of Set 11 | saint-augustin
# Processing Record 25 of Set 11 | jiaocheng
# Processing Record 26 of Set 11 | abha
# Processing Record 27 of Set 11 | teknaf
# Processing Record 28 of Set 11 | ndele
# Processing Record 29 of Set 11 | ardesen
# Processing Record 30 of Set 11 | halifax
# Processing Record 31 of Set 11 | jena
# City not found. Skipping...
# Processing Record 32 of Set 11 | rungata
# Processing Record 33 of Set 11 | vestmanna
# Processing Record 34 of Set 11 | ludvika
# Processing Record 35 of Set 11 | college
# Processing Record 36 of Set 11 | padang
# Processing Record 37 of Set 11 | sarai mir
# Processing Record 38 of Set 11 | araouane
# Processing Record 39 of Set 11 | sydney mines
# Processing Record 40 of Set 11 | sumbawanga
# Processing Record 41 of Set 11 | jieshou
# City not found. Skipping...
# Processing Record 42 of Set 11 | masjed-e soleyman
# Processing Record 43 of Set 11 | sioux falls
# City not found. Skipping...
# Processing Record 44 of Set 11 | do rud
# Processing Record 45 of Set 11 | akom
# Processing Record 46 of Set 11 | peniche
# Processing Record 47 of Set 11 | kolondieba
# City not found. Skipping...
# Processing Record 48 of Set 11 | glubokoe
# Processing Record 49 of Set 11 | khani
# Processing Record 50 of Set 11 | ulladulla
# Processing Record 1 of Set 12 | valdivia
# Processing Record 2 of Set 12 | palmer
# Processing Record 3 of Set 12 | pondicherry
# City not found. Skipping...
# Processing Record 4 of Set 12 | atka
# Processing Record 5 of Set 12 | suzhou
# Processing Record 6 of Set 12 | ponazyrevo
# Processing Record 7 of Set 12 | tateyama
# Processing Record 8 of Set 12 | eureka
# Processing Record 9 of Set 12 | tombouctou
# Processing Record 10 of Set 12 | cabo san lucas
# Processing Record 11 of Set 12 | staryy nadym
# Processing Record 12 of Set 12 | manzil salim
# Processing Record 13 of Set 12 | isahaya
# City not found. Skipping...
# Processing Record 14 of Set 12 | thilogne
# Processing Record 15 of Set 12 | maraa
# Processing Record 16 of Set 12 | walvis bay
# Processing Record 17 of Set 12 | bainbridge
# Processing Record 18 of Set 12 | makat
# Processing Record 19 of Set 12 | vila franca do campo
# Processing Record 20 of Set 12 | la palma
# Processing Record 21 of Set 12 | pipri
# Processing Record 22 of Set 12 | kapuskasing
# Processing Record 23 of Set 12 | heerenveen
# Processing Record 24 of Set 12 | saint-pierre
# City not found. Skipping...
# Processing Record 25 of Set 12 | stamsund
# Processing Record 26 of Set 12 | digha
# Processing Record 27 of Set 12 | san cristobal
# Processing Record 28 of Set 12 | masallatah
# Processing Record 29 of Set 12 | san ramon
# Processing Record 30 of Set 12 | dogondoutchi
# Processing Record 31 of Set 12 | gilgit
# Processing Record 32 of Set 12 | bombay
# City not found. Skipping...
# Processing Record 33 of Set 12 | grand centre
# Processing Record 34 of Set 12 | oyama
# Processing Record 35 of Set 12 | bella vista
# Processing Record 36 of Set 12 | goderich
# Processing Record 37 of Set 12 | tikapur
# Processing Record 38 of Set 12 | havoysund
# Processing Record 39 of Set 12 | bethel
# Processing Record 40 of Set 12 | nizwa
# Processing Record 41 of Set 12 | lagunas
# Processing Record 42 of Set 12 | basoko
# Processing Record 43 of Set 12 | morro da fumaca
# Processing Record 44 of Set 12 | wattegama
# Processing Record 45 of Set 12 | curanilahue
# Processing Record 46 of Set 12 | kavaratti
# City not found. Skipping...
# Processing Record 47 of Set 12 | lolua
# Processing Record 48 of Set 12 | aripuana
# Processing Record 49 of Set 12 | hengyang
# Processing Record 50 of Set 12 | santa fe
# Processing Record 1 of Set 13 | leh
# Processing Record 2 of Set 13 | minyar
# Processing Record 3 of Set 13 | thinadhoo
# Processing Record 4 of Set 13 | marzuq
# Processing Record 5 of Set 13 | muros
# Processing Record 6 of Set 13 | the pas
# Processing Record 7 of Set 13 | alyangula
# Processing Record 8 of Set 13 | ponta delgada
# City not found. Skipping...
# Processing Record 9 of Set 13 | samusu
# Processing Record 10 of Set 13 | yulara
# Processing Record 11 of Set 13 | bolu
# Processing Record 12 of Set 13 | sahbuz
# Processing Record 13 of Set 13 | quixere
# Processing Record 14 of Set 13 | jinka
# Processing Record 15 of Set 13 | druzhba
# Processing Record 16 of Set 13 | velur
# Processing Record 17 of Set 13 | ranong
# Processing Record 18 of Set 13 | chekmagush
# Processing Record 19 of Set 13 | oranjemund
# Processing Record 20 of Set 13 | jacmel
# Processing Record 21 of Set 13 | makakilo city
# Processing Record 22 of Set 13 | zalantun
# Processing Record 23 of Set 13 | vostok
# Processing Record 24 of Set 13 | honiara
# Processing Record 25 of Set 13 | asau
# Processing Record 26 of Set 13 | bria
# Processing Record 27 of Set 13 | shenjiamen
# Processing Record 28 of Set 13 | peterhead
# Processing Record 29 of Set 13 | mildura
# Processing Record 30 of Set 13 | calella
# Processing Record 31 of Set 13 | malakal
# Processing Record 32 of Set 13 | hobyo
# Processing Record 33 of Set 13 | svetlaya
# Processing Record 34 of Set 13 | bonavista
# Processing Record 35 of Set 13 | inuvik
# Processing Record 36 of Set 13 | burnie
# Processing Record 37 of Set 13 | ormara
# Processing Record 38 of Set 13 | mantua
# City not found. Skipping...
# Processing Record 39 of Set 13 | chengmai
# Processing Record 40 of Set 13 | acheng
# Processing Record 41 of Set 13 | luang prabang
# Processing Record 42 of Set 13 | norsup
# City not found. Skipping...
# Processing Record 43 of Set 13 | karauzyak
# City not found. Skipping...
# Processing Record 44 of Set 13 | jinchengjiang
# Processing Record 45 of Set 13 | ulundi
# Processing Record 46 of Set 13 | caravelas
# Processing Record 47 of Set 13 | severnyy
# Processing Record 48 of Set 13 | buala
# City not found. Skipping...
# Processing Record 49 of Set 13 | kamenskoye
# Processing Record 50 of Set 13 | vardo
# Processing Record 1 of Set 14 | sao desiderio
# Processing Record 2 of Set 14 | aureliana
# Processing Record 3 of Set 14 | miram shah
# Processing Record 4 of Set 14 | tongren
# Processing Record 5 of Set 14 | kyaukse
# Processing Record 6 of Set 14 | kurchum
# Processing Record 7 of Set 14 | jalu
# Processing Record 8 of Set 14 | sacama
# Processing Record 9 of Set 14 | maceio
# Processing Record 10 of Set 14 | labrea
# Processing Record 11 of Set 14 | astakos
# Processing Record 12 of Set 14 | iqaluit
# Processing Record 13 of Set 14 | port macquarie
# Processing Record 14 of Set 14 | pankrushikha
# Processing Record 15 of Set 14 | khandyga
# Processing Record 16 of Set 14 | tikamgarh
# Processing Record 17 of Set 14 | sattahip
# City not found. Skipping...
# Processing Record 18 of Set 14 | louisbourg
# Processing Record 19 of Set 14 | santa lucia
# Processing Record 20 of Set 14 | dolores hidalgo
# Processing Record 21 of Set 14 | tessalit
# City not found. Skipping...
# Processing Record 22 of Set 14 | ngukurr
# Processing Record 23 of Set 14 | sengiley
# Processing Record 24 of Set 14 | salinopolis
# Processing Record 25 of Set 14 | quartucciu
# Processing Record 26 of Set 14 | segezha
# Processing Record 27 of Set 14 | kousseri
# Processing Record 28 of Set 14 | andenes
# Processing Record 29 of Set 14 | port washington
# Processing Record 30 of Set 14 | nueva germania
# Processing Record 31 of Set 14 | ormstown
# Processing Record 32 of Set 14 | isla aguada
# City not found. Skipping...
# Processing Record 33 of Set 14 | taburi
# Processing Record 34 of Set 14 | grabouw
# Processing Record 35 of Set 14 | lazaro cardenas
# City not found. Skipping...
# Processing Record 36 of Set 14 | kegayli
# Processing Record 37 of Set 14 | winkler
# Processing Record 38 of Set 14 | majene
# Processing Record 39 of Set 14 | punta de bombon
# Processing Record 40 of Set 14 | egvekinot
# Processing Record 41 of Set 14 | hargeysa
# Processing Record 42 of Set 14 | creel
# Processing Record 43 of Set 14 | ceres
# Processing Record 44 of Set 14 | port hawkesbury
# City not found. Skipping...
# Processing Record 45 of Set 14 | siutu
# Processing Record 46 of Set 14 | bud
# Processing Record 47 of Set 14 | pietarsaari
# Processing Record 48 of Set 14 | vierzon
# Processing Record 49 of Set 14 | tezu
# Processing Record 50 of Set 14 | yantai
# Processing Record 1 of Set 15 | kampot
# Processing Record 2 of Set 15 | liberal
# Processing Record 3 of Set 15 | carmen
# Processing Record 4 of Set 15 | wakkanai
# Processing Record 5 of Set 15 | bayir
# Processing Record 6 of Set 15 | bukama
# Processing Record 7 of Set 15 | huron
# Processing Record 8 of Set 15 | polson
# Processing Record 9 of Set 15 | lavrentiya
# Processing Record 10 of Set 15 | bondo
# Processing Record 11 of Set 15 | rosetta
# Processing Record 12 of Set 15 | bazaliya
# Processing Record 13 of Set 15 | angoche
# Processing Record 14 of Set 15 | sakakah
# Processing Record 15 of Set 15 | moshupa
# Processing Record 16 of Set 15 | boali
# Processing Record 17 of Set 15 | purpe
# Processing Record 18 of Set 15 | moron
# City not found. Skipping...
# Processing Record 19 of Set 15 | marcona
# Processing Record 20 of Set 15 | barra do bugres
# Processing Record 21 of Set 15 | areosa
# Processing Record 22 of Set 15 | paragominas
# Processing Record 23 of Set 15 | pathein
# Processing Record 24 of Set 15 | waingapu
# Processing Record 25 of Set 15 | comodoro rivadavia
# Processing Record 26 of Set 15 | saurimo
# City not found. Skipping...
# Processing Record 27 of Set 15 | yanchukan
# Processing Record 28 of Set 15 | xinqing
# Processing Record 29 of Set 15 | kuala perlis
# Processing Record 30 of Set 15 | la ronge
# Processing Record 31 of Set 15 | marsa matruh
# Processing Record 32 of Set 15 | poya
# Processing Record 33 of Set 15 | sambava
# Processing Record 34 of Set 15 | wahiawa
# Processing Record 35 of Set 15 | nabire
# Processing Record 36 of Set 15 | winsum
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0     Provideniya      RU  64.3833 -173.3000     53.71        58          40
# 1  Ribeira Grande      PT  38.5167  -28.7000     74.08        78           3
# 2          Broome      US  42.2506  -75.8330     78.71        75          20
# 3         Bubaque      GW  11.2833  -15.8333     79.41        83          65
# 4    Punta Arenas      CL -53.1500  -70.9167     37.51        81         100
# 5         Qaanaaq      GL  77.4840  -69.3632     34.65        59           0
# 6            Melo      UY -32.3667  -54.1833     44.96        94          21
# 7       Mount Isa      AU -20.7333  139.5000     73.17        18           0
# 8          Tutoia      BR  -2.7619  -42.2744     78.37        80          20
# 9         Ushuaia      AR -54.8000  -68.3000     37.06        60          75
#
#    Wind Speed Current Description
# 0       13.42    scattered clouds
# 1       11.81           clear sky
# 2       10.36          few clouds
# 3       13.02          light rain
# 4       10.36     overcast clouds
# 5        4.74           clear sky
# 6       10.65          few clouds
# 7       12.66           clear sky
# 8       11.97          few clouds
# 9        5.75       broken clouds

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")

# %%
len(city_data_df)
# Out:
# 663
